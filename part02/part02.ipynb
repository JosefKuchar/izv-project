# %%
# %load_ext autoreload
import analysis
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
raw_df = analysis.load_data("data/data.zip")
raw_df.head()
# Out:
#            p1  p36  p37         p2a  weekday(p2a)   p2b  p6  p7  p8  p9  ...  \
# 0  2100160001    4  NaN  2016-01-01             5    55   1   1   0   2  ...
# 1  2100160002    4  NaN  2016-01-01             5   130   1   3   0   2  ...
# 2  2100160003    5  NaN  2016-01-01             5   100   1   2   0   2  ...
# 3  2100160004    6  NaN  2016-01-01             5   120   9   0   0   2  ...
# 4  2100160005    6  NaN  2016-01-01             5  2560   2   0   0   2  ...
#
#      l         n    o                       p       q         r         s  \
# 0  NaN  711403.0  NaN  Souhlasnýsesměremúseku  Pomalý  554782.0  451622.0
# 1  NaN       NaN  NaN                     NaN     NaN       NaN       NaN
# 2  NaN       NaN  NaN                     NaN     NaN       NaN       NaN
# 3  NaN       NaN  NaN                     NaN     NaN       NaN       NaN
# 4  NaN       NaN  NaN                     NaN     NaN       NaN       NaN
#
#                     t  p5a  region
# ...

# %%
# %autoreload 2
clean_df = analysis.parse_data(raw_df, True)
# Out:
# orig_size=1088.3 MB
# new_size=385.9 MB

# %%
# %autoreload 2
analysis.plot_state(clean_df)

# %%
# %autoreload 2
analysis.plot_alcohol(clean_df)

# %%
# %autoreload 2
analysis.plot_fault(clean_df)
