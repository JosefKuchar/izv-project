# %%
# %load_ext autoreload
import geo
import pandas as pd

# %%
# %autoreload 2
g = geo.make_geo(pd.read_pickle("accidents.pkl.gz"))

# %%
# %autoreload 2
geo.plot_geo(g, "geo1.png", True)

# %%
# %autoreload 2
geo.plot_cluster(g, "geo2.png", True)
