# %% [markdown]
# This notebook is just for checking outputs of the functions in the `part01.py` file.

# %%
# %load_ext autoreload
import part01

# %%
# %autoreload 2
def f(x): return 10 * x + 2
part01.integrate(f, 0, 1, 100)
# Out:
# 7.000000000000001

# %%
# %autoreload 2
part01.generate_graph([1.0, 1.5, 2.0])

# %%
# %autoreload 2
part01.generate_sinus()

# %%
# %autoreload 2
part01.download_data()
# Out:
# [{'position': 'Cheb', 'lat': 50.0683, 'long': 12.3913, 'height': 483.0},
#  {'position': 'Karlovy Vary',
#   'lat': 50.2016,
#   'long': 12.9139,
#   'height': 603.0},
#  {'position': 'Přimda', 'lat': 49.6694, 'long': 12.6779, 'height': 742.76},
#  {'position': 'Kopisty', 'lat': 50.544, 'long': 13.6227, 'height': 240.0},
#  {'position': 'Tušimice', 'lat': 50.3765, 'long': 13.3279, 'height': 322.4},
#  {'position': 'Plzeň-Mikulka',
#   'lat': 49.7645,
#   'long': 13.3787,
#   'height': 359.8},
#  {'position': 'Churáňov', 'lat': 49.0683, 'long': 13.615, 'height': 1117.8},
#  {'position': 'Milešovka', 'lat': 50.5549, 'long': 13.9306, 'height': 830.5},
#  {'position': 'Kocelovice', 'lat': 49.4672, 'long': 13.8385, 'height': 519.0},
#  {'position': 'Ústí nad Labem',
#   'lat': 50.6833,
#   'long': 14.041,
#   'height': 375.39},
#  {'position': 'Doksany', 'lat': 50.4587, 'long': 14.1699, 'height': 158.0},
#  {'position': 'Praha-Ruzyně',
#   'lat': 50.1003,
#   'long': 14.2555,
# ...
